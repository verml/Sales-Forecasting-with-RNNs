# %%
################################
#
# Dataset: https://www.kaggle.com/tevecsystems/retail-sales-forecasting
#
# The data contains the sales and price of a product at the end of each day
# We will forecast the sales for next day, given the sales for the last few days
# Using LSTMs cells and RNN
#
# Author: Anurag Dwarakanath
################################

# %%
import tensorflow as tf
import pandas
import numpy as np

# %%
# Constants
DATAFILE_TRAIN = "/home/ubuntu/anurag/rnn/mock_kaggle_edit_train.csv" 

DATAFILE_VALIDATE = "/home/ubuntu/anurag/rnn/mock_kaggle_edit_validate.csv"

# The original data is here: https://www.kaggle.com/tevecsystems/retail-sales-forecasting
# The original data was simplified to consider only 'date', 'sales', 'price'
# However, we will consider only 'sales' & 'date'

TIME_STEPS = 10 # i.e. look at the past 10 days and forecast
NUMBER_OF_DAYS_TO_FORECAST = 1 # for now we will only forecast the next day's sales

BATCH_SIZE=100

NUM_EPOCHS=100

LSTM_UNITS = 250

# %%
#ingest the data
data_train = pandas.read_csv(DATAFILE_TRAIN) # data will be an array of dict. E.g. data['sales'][0]
data_validate = pandas.read_csv(DATAFILE_VALIDATE)

# %%
# let's print the first 5 rows of the data
data_train.head()
# Out:
#        date  sales  price
# 0  1/1/2014      0   1.29
# 1  1/2/2014     70   1.29
# 2  1/3/2014     59   1.29
# 3  1/4/2014     93   1.29
# 4  1/5/2014     96   1.29

# %%
# Create the training & validation data

numTrainingData = len(data_train)
numValidationData = len(data_validate)

trainingData_date = data_train['date'][0:numTrainingData]
trainingData_sales = data_train['sales'][0:numTrainingData]
trainindData_price = data_train['price'][0:numTrainingData]

validationData_date = data_validate['date'][0: numValidationData]
validationData_sales = data_validate['sales'][0: numValidationData]
validationData_price = data_validate['price'][0: numValidationData]

# %%
trainingData_sales
# Out:
# 0        0
# 1       70
# 2       59
# 3       93
# 4       96
# 5      145
# 6      179
# 7      321
# 8      125
# 9       88
# 10     188
# 11     121
# 12     134
# 13      80
# 14      82
# 15      94
# 16     159
# 17     199
# 18     104
# 19      70
# 20     127
# 21      96
# 22      75
# 23     198
# 24     168
# 25     125
# 26      86
# 27     222
# 28     272
# 29     209
#       ...
# 720    100
# 721      9
# 722      0
# 723      0
# 724      0
# 725      3
# 726      0
# 727      0
# 728      3
# 729      3
# 730      0
# 731      2
# 732      0
# 733      3
# 734      0
# 735    103
# 736    164
# 737    118
# 738     65
# 739     24
# 740      0
# 741      1
# 742      0
# 743      1
# 744     60
# 745    103
# 746    263
# 747    189
# 748    197
# 749    105
# Name: sales, Length: 750, dtype: int64

# %%
print(len(trainingData_sales))
print(len(validationData_sales))
# Out:
# 750
# 187

# %%
# Normalise the training and validation data.
# We use the (x - min)/(range) to normalise, where range = (max - min)
# This will put the values between 0 & 1
trainingData_sales_min = min(trainingData_sales)
trainingData_sales_max = max(trainingData_sales)
trainingData_sales_range = trainingData_sales_max - trainingData_sales_min
trainingData_sales_normalised = [(i - trainingData_sales_min)/trainingData_sales_range for i in trainingData_sales]

validationData_sales_normalised = [(i - trainingData_sales_min)/trainingData_sales_range for i in validationData_sales]
# Note the validation data uses the max & min values of Training Data

# %%
trainingData_sales_normalised
# Out:
# [0.0,
#  0.0,
#  0.0018450184501845018,
#  0.0,
#  0.0018450184501845018,
#  0.11070110701107011,
#  0.1900369003690037,
#  0.48523985239852396,
#  0.34870848708487084,
#  0.3634686346863469,
#  0.1937269372693727]

# %%
# we will create the set of sequences
trainingDataSequence_sales = np.zeros(shape=(len(trainingData_sales)-TIME_STEPS-NUMBER_OF_DAYS_TO_FORECAST+1, TIME_STEPS, 1))
targetDataSequence_sales = np.zeros(shape=(len(trainingData_sales)-TIME_STEPS-NUMBER_OF_DAYS_TO_FORECAST+1, NUMBER_OF_DAYS_TO_FORECAST))
start = 0
for i in range(TIME_STEPS, len(trainingData_sales)-NUMBER_OF_DAYS_TO_FORECAST+1):
    trainingDataSequence_sales[start,:,0]=trainingData_sales_normalised[start:i]
    targetDataSequence_sales[start] = trainingData_sales_normalised[i:i+NUMBER_OF_DAYS_TO_FORECAST]
    start=start+1

## MT: make sure the sequences do not miss out any data
# maybe create predictable data (1, 2, 3, 4) then put completely rubbish data (23434) at the end.. this should be picked up in training

# %% [markdown]
# ## The format of the data sequences is as follows:
#
# trainingDataSequence_sales = \[sales_day1 sales_day2 sales_day3 ... sales_day10\]
#
# targetDataSequence_sales = \[sales_day11\]
#
# Although the trainingDataSequence_sales can be captured through a 2D array, we use 3D (i.e. shape = (num of sequence, time steps, 1) ) because the tensor input for the LSTM cell expects a 3D input. The third dimension is the *num of features*  of each data point (in our case, it is a single dimension).

# %%
# Print the first few sequences of the sales that have been created
[trainingDataSequence_sales[i, :, 0] for i in range(3)]
# Out:
# [array([0.        , 0.12915129, 0.10885609, 0.17158672, 0.17712177,
#         0.26752768, 0.3302583 , 0.59225092, 0.23062731, 0.16236162]),
#  array([0.12915129, 0.10885609, 0.17158672, 0.17712177, 0.26752768,
#         0.3302583 , 0.59225092, 0.23062731, 0.16236162, 0.34686347]),
#  array([0.10885609, 0.17158672, 0.17712177, 0.26752768, 0.3302583 ,
#         0.59225092, 0.23062731, 0.16236162, 0.34686347, 0.22324723])]

# %%
#Print the first few target sales
[targetDataSequence_sales[i] for i in range(3)]
# Out:
# [array([0.34686347]), array([0.22324723]), array([0.24723247])]

# %% [markdown]
# ###### Observe that the first sales target (0.34686347) becomes the last day sales of the next triainingDataSequence
#
# i.e. targetDataSequence_sales\[i\] = targetDataSequence_sales\[i+1,TIME_STEPS-1,0\]

# %%
# since we are making each sequence independent to each other,
# the order of the sequences can be shuffled.
# Note that we need to ensure the target and the train sequences are in the same order
a = np.arange(len(targetDataSequence_sales))
np.random.shuffle(a)
trainingDataSequence_sales_shuffle = np.zeros(shape=(len(trainingData_sales)-TIME_STEPS-NUMBER_OF_DAYS_TO_FORECAST+1, TIME_STEPS, 1))
targetDataSequence_sales_shuffle = np.zeros(shape=(len(trainingData_sales)-TIME_STEPS-NUMBER_OF_DAYS_TO_FORECAST+1, NUMBER_OF_DAYS_TO_FORECAST))

loc=0
for i in a:
    trainingDataSequence_sales_shuffle[loc] = trainingDataSequence_sales[i]
    targetDataSequence_sales_shuffle[loc] = targetDataSequence_sales[i]
    loc+=1

trainingDataSequence_sales = trainingDataSequence_sales_shuffle
targetDataSequence_sales = targetDataSequence_sales_shuffle

# %%
# Build the seqeunces for validation
validationDataSequence_sales = np.zeros(shape=(len(validationData_sales) - TIME_STEPS - NUMBER_OF_DAYS_TO_FORECAST + 1, TIME_STEPS, 1 ))
validationDataSequence_sales_target = np.zeros(shape=(len(validationData_sales) - TIME_STEPS - NUMBER_OF_DAYS_TO_FORECAST + 1, NUMBER_OF_DAYS_TO_FORECAST))

start = 0
for i in range(TIME_STEPS, len(validationData_sales)-NUMBER_OF_DAYS_TO_FORECAST + 1):
    validationDataSequence_sales[start, :, 0] = validationData_sales_normalised[start:i]
    validationDataSequence_sales_target[start] = validationData_sales_normalised[i:i+NUMBER_OF_DAYS_TO_FORECAST]
    start+=1

# %%
#build the RNN model
tf.reset_default_graph()

inputSequencePlaceholder = tf.placeholder(dtype=tf.float32, shape=(None, TIME_STEPS, 1), name='inputSequencePlaceholder')
targetPlaceholder = tf.placeholder(dtype=tf.float32, shape=(None, NUMBER_OF_DAYS_TO_FORECAST), name='targetPlaceholder')

#cell = tf.contrib.cudnn_rnn.CudnnLSTM(num_layers=1, num_units=5, name='LSTM_cell')
cell = tf.nn.rnn_cell.LSTMCell(num_units=LSTM_UNITS, name='LSTM_cell')


output, state = tf.nn.dynamic_rnn(cell=cell, inputs=inputSequencePlaceholder, dtype=tf.float32)
#output is of shape (Batch, time, num_units)

lastCellOutput = output[:, -1,:]

# %%
print('output:',output)
print('state:', state)
print('lastCellOutput:', lastCellOutput)
# Out:
# output: Tensor("rnn/transpose_1:0", shape=(?, 10, 250), dtype=float32)
# state: LSTMStateTuple(c=<tf.Tensor 'rnn/while/Exit_3:0' shape=(?, 250) dtype=float32>, h=<tf.Tensor 'rnn/while/Exit_4:0' shape=(?, 250) dtype=float32>)
# lastCellOutput: Tensor("strided_slice:0", shape=(?, 250), dtype=float32)

# %% [markdown]
# ## Understanding the type and shape of **output** & **state**
# the RNN gives two outputs for every sequence of input: a) output & b) state.
#
# **output** is the per time step output (i.e. output from each time step and which is represented as a_t in our notes). Thus it has a shape of (Batch, 10, 25). We are interested only in the final time step output (i.e. Batch, 9, 250) and this is captured by lastCellOutput
#
# the **state** is the value of the internal parameters of the LSTM that can be propogated to the next sequence if need be. The state is of type LSTMStateTuple which contains two tensors of shape (batch, 250) each.

# %%
#build the output layer from the RNN outputs
weights = tf.Variable(initial_value=tf.truncated_normal(shape=(LSTM_UNITS, NUMBER_OF_DAYS_TO_FORECAST)))
bias = tf.Variable(initial_value=tf.ones(shape=(NUMBER_OF_DAYS_TO_FORECAST)))

forecast = tf.matmul(a=lastCellOutput, b=weights) + bias

# bring back the forecast to the original scale
forecast_originalScale = forecast * trainingData_sales_range + trainingData_sales_min

# %%
print(forecast)
print(forecast_originalScale)
# Out:
# Tensor("add:0", shape=(?, 1), dtype=float32)
# Tensor("add_1:0", shape=(?, 1), dtype=float32)

# %% [markdown]
# the **forecast** is the layer that computes the final forecast. this is the y_hat in our notes. **forecast** will have a shape of (Batch, 1)

# %%
loss = tf.reduce_mean(tf.squared_difference(x=forecast, y=targetPlaceholder))

# %%
optimizer = tf.train.AdamOptimizer(learning_rate=0.1)
minimize_step = optimizer.minimize(loss)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    
    #start the training
    for e in range(NUM_EPOCHS):
        print('starting training for epoch:', e+1)
        
        startLocation=0
        iteration=0
        for iteration in range(int(len(targetDataSequence_sales)/BATCH_SIZE)):
            print('epoch:', e+1, ' iteration:', iteration+1)
            trainingBatchInput = trainingDataSequence_sales[startLocation:startLocation+BATCH_SIZE, :, :]
            trainingBatchTarget = targetDataSequence_sales[startLocation:startLocation+BATCH_SIZE]
            
            _, lsBatch, forecastBatch, forecastBatch_originalScale = sess.run([minimize_step, loss, forecast, forecast_originalScale], feed_dict={inputSequencePlaceholder: trainingBatchInput,
                                                                                            targetPlaceholder: trainingBatchTarget})
            
            if ((iteration+1) % 1 == 0):
                print('got a loss of:', lsBatch)
                print('the forecast of first 5 normalised are:', forecastBatch[0:5])
                print('while the actuals were normalised     :', trainingBatchTarget[0:5])
                print('the forecast of first 5 orignal scale are:', forecastBatch_originalScale[0:5])
                print('while the actuals were original scale     :', trainingBatchTarget[0:5]* trainingData_sales_range + trainingData_sales_min)
            
            startLocation+=BATCH_SIZE
        
        #pick up the training data that does not fit into BATCH_SIZE
        if (len(targetDataSequence_sales) > startLocation):
            print('epoch:', e+1, ' iteration:', iteration+1)
            trainingBatchInput = trainingDataSequence_sales[startLocation:len(targetDataSequence_sales), :, :]
            trainingBatchTarget = targetDataSequence_sales[startLocation:len(targetDataSequence_sales)]
            
            _, lsBatch, forecastBatch, forecastBatch_originalScale = sess.run([minimize_step, loss, forecast, forecast_originalScale], feed_dict={inputSequencePlaceholder: trainingBatchInput,
                                                                                            targetPlaceholder: trainingBatchTarget})
            
            print('got a loss of:', lsBatch)
            print('the forecast of first 5 normalised are:', forecastBatch[0:5])
            print('while the actuals were normalised     :', trainingBatchTarget[0:5])
            print('the forecast of first 5 orignal scale are:', forecastBatch_originalScale[0:5])
            print('while the actuals were original scale     :', trainingBatchTarget[0:5]* trainingData_sales_range + trainingData_sales_min)
    
    
        #end of 1 epoch. Perform validation
        totalValidationLoss = 0
        startLocation=0
        print('starting validation')
        for iter in range(len(validationDataSequence_sales)//BATCH_SIZE):
            validationBatchInput = validationDataSequence_sales[startLocation: startLocation+BATCH_SIZE, :, :]
            validationBatchTarget = validationDataSequence_sales_target[startLocation: startLocation+BATCH_SIZE]
            
            validationLsBatch, validationForecastBatch, validationForecastBatch_originalScale = sess.run([loss, forecast, forecast_originalScale], feed_dict={inputSequencePlaceholder: validationBatchInput,
                                                                                              targetPlaceholder: validationBatchTarget})
            
           
            startLocation+=BATCH_SIZE
            totalValidationLoss+= validationLsBatch
            
            print('first five predictions:', validationForecastBatch[0:5])
            print('first five actuals    :', validationBatchTarget[0:5])
            print('the forecast of first 5 orignal scale are:', validationForecastBatch_originalScale[0:5])
            print('while the actuals were original scale     :', validationBatchTarget[0:5]* trainingData_sales_range + trainingData_sales_min)
    
        
        if(startLocation < len(validationDataSequence_sales)):
            validationBatchInput = validationDataSequence_sales[startLocation: len(validationDataSequence_sales)]
            validationBatchTarget = validationDataSequence_sales_target[startLocation: len(validationDataSequence_sales)]
            
            validationLsBatch, validationForecastBatch = sess.run([loss, forecast], feed_dict={inputSequencePlaceholder: validationBatchInput,
                                                                                              targetPlaceholder: validationBatchTarget})
            
            totalValidationLoss+= validationLsBatch
        
        #validation completed.
        print('Validation completed after epoch:',e+1 ,'. Total validation loss:', totalValidationLoss)
# Out:
# starting training for epoch: 1
# epoch: 1  iteration: 1
# got a loss of: 0.7606255
# the forecast of first 5 normalised are: [[1.0147064]
#  [1.0091066]
#  [1.0190531]
#  [1.0073123]
#  [1.0238214]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[549.9708 ]
#  [546.9358 ]
#  [552.3268 ]
#  [545.96326]
#  [554.9112 ]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 1  iteration: 2
# got a loss of: 7710.0713
# the forecast of first 5 normalised are: [[-87.68513]
#  [-87.68503]
#  [-87.5487 ]
#  [-87.68245]
#  [-87.54081]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[-47525.34 ]
#  [-47525.285]
#  [-47451.395]
#  [-47523.887]
#  [-47447.117]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 1  iteration: 3
# got a loss of: 280.9935
# the forecast of first 5 normalised are: [[17.329782]
#  [16.7704  ]
#  [16.760649]
#  [17.019808]
#  [15.971851]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[9392.742]
#  [9089.557]
#  [9084.271]
#  [9224.735]
#  [8656.743]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 1  iteration: 4
# got a loss of: 1085.6681
# the forecast of first 5 normalised are: [[-22.408398]
#  [-22.429438]
#  [-22.462626]
#  [-22.423983]
#  [-22.46807 ]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[-12145.352]
#  [-12156.755]
#  [-12174.743]
#  [-12153.799]
#  [-12177.693]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 1  iteration: 5
# got a loss of: 408.51282
# the forecast of first 5 normalised are: [[-19.267109]
#  [-20.190825]
#  [-20.269598]
#  [-20.230314]
#  [-19.97727 ]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[-10442.773]
#  [-10943.427]
#  [-10986.122]
#  [-10964.83 ]
#  [-10827.681]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 1  iteration: 6
# got a loss of: 2009.9011
# the forecast of first 5 normalised are: [[-44.922764]
#  [-45.749973]
#  [-46.45727 ]
#  [-45.200134]
#  [-45.064507]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[-24348.139]
#  [-24796.486]
#  [-25179.842]
#  [-24498.473]
#  [-24424.963]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 1  iteration: 7
# got a loss of: 93.85949
# the forecast of first 5 normalised are: [[-12.710831 ]
#  [-11.346182 ]
#  [ -8.827736 ]
#  [ -5.7146773]
#  [ -3.8399053]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[-6889.27  ]
#  [-6149.6304]
#  [-4784.633 ]
#  [-3097.3552]
#  [-2081.2288]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 1  iteration: 7
# got a loss of: 0.73210037
# the forecast of first 5 normalised are: [[ 0.68692523]
#  [ 1.505125  ]
#  [ 0.29305667]
#  [-0.79680157]
#  [ 2.3907344 ]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 372.31348]
#  [ 815.7778 ]
#  [ 158.83672]
#  [-431.86646]
#  [1295.7781 ]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[-2.1075952]
#  [-5.131657 ]
#  [-5.5616255]
#  [-3.0217595]
#  [-1.89744  ]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[-1142.3167]
#  [-2781.3582]
#  [-3014.4011]
#  [-1637.7937]
#  [-1028.4125]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 1 . Total validation loss: 40.36907196044922
# starting training for epoch: 2
# epoch: 2  iteration: 1
# got a loss of: 18.064186
# the forecast of first 5 normalised are: [[-6.3960238]
#  [-3.9698968]
#  [-5.888052 ]
#  [-3.4294925]
#  [-3.168006 ]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[-3466.6448]
#  [-2151.684 ]
#  [-3191.3242]
#  [-1858.7849]
#  [-1717.0592]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 2  iteration: 2
# got a loss of: 74.23212
# the forecast of first 5 normalised are: [[-8.651358]
#  [-8.535019]
#  [-9.40555 ]
#  [-8.444527]
#  [-9.328167]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[-4689.0356]
#  [-4625.9805]
#  [-5097.808 ]
#  [-4576.9336]
#  [-5055.8667]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 2  iteration: 3
# got a loss of: 16.922934
# the forecast of first 5 normalised are: [[4.7618465]
#  [2.8916621]
#  [4.85203  ]
#  [4.6931   ]
#  [5.0767565]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[2580.921 ]
#  [1567.2809]
#  [2629.8   ]
#  [2543.6602]
#  [2751.602 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 2  iteration: 4
# got a loss of: 11.761117
# the forecast of first 5 normalised are: [[3.6306756]
#  [3.9330347]
#  [3.6352031]
#  [3.7735777]
#  [3.5700862]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[1967.8262]
#  [2131.7048]
#  [1970.2802]
#  [2045.279 ]
#  [1934.9867]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 2  iteration: 5
# got a loss of: 8.140674
# the forecast of first 5 normalised are: [[2.995833 ]
#  [2.9921937]
#  [3.1002407]
#  [3.070889 ]
#  [2.9765315]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[1623.7415]
#  [1621.769 ]
#  [1680.3304]
#  [1664.4219]
#  [1613.28  ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 2  iteration: 6
# got a loss of: 3.861577
# the forecast of first 5 normalised are: [[2.0407336]
#  [2.1139476]
#  [2.0197172]
#  [1.9969075]
#  [2.0329185]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[1106.0776]
#  [1145.7596]
#  [1094.6868]
#  [1082.3239]
#  [1101.8418]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 2  iteration: 7
# got a loss of: 0.54448146
# the forecast of first 5 normalised are: [[0.79125875]
#  [0.80722153]
#  [0.84178346]
#  [0.78638095]
#  [0.9290639 ]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[428.86224]
#  [437.51407]
#  [456.24664]
#  [426.21848]
#  [503.55264]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 2  iteration: 7
# got a loss of: 0.023430549
# the forecast of first 5 normalised are: [[0.1786828 ]
#  [0.14889598]
#  [0.2136674 ]
#  [0.2766881 ]
#  [0.10604084]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 96.84608 ]
#  [ 80.70162 ]
#  [115.807724]
#  [149.96495 ]
#  [ 57.474133]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[-0.12937951]
#  [-0.13706827]
#  [-0.1609577 ]
#  [-0.20848393]
#  [-0.17599726]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[ -70.123695]
#  [ -74.291   ]
#  [ -87.23907 ]
#  [-112.99829 ]
#  [ -95.39051 ]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 2 . Total validation loss: 0.33362600952386856
# starting training for epoch: 3
# epoch: 3  iteration: 1
# got a loss of: 0.07188864
# the forecast of first 5 normalised are: [[-0.03175521]
#  [-0.13160634]
#  [-0.17163229]
#  [-0.0849545 ]
#  [-0.17788398]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[-17.211323]
#  [-71.330635]
#  [-93.024704]
#  [-46.045338]
#  [-96.41312 ]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 3  iteration: 2
# got a loss of: 0.10616809
# the forecast of first 5 normalised are: [[-0.11929655]
#  [-0.13725543]
#  [-0.06572318]
#  [-0.18358207]
#  [-0.04746294]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[-64.65873 ]
#  [-74.39244 ]
#  [-35.621964]
#  [-99.50148 ]
#  [-25.724915]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 3  iteration: 3
# got a loss of: 0.07606939
# the forecast of first 5 normalised are: [[-0.07181966]
#  [-0.14380836]
#  [-0.05006135]
#  [-0.02126932]
#  [-0.06197572]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[-38.926258]
#  [-77.94414 ]
#  [-27.13325 ]
#  [-11.527972]
#  [-33.59084 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 3  iteration: 4
# got a loss of: 0.04066019
# the forecast of first 5 normalised are: [[ 0.03757834]
#  [-0.04729843]
#  [-0.0407089 ]
#  [-0.00749481]
#  [ 0.0460583 ]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 20.367462 ]
#  [-25.63575  ]
#  [-22.064224 ]
#  [ -4.0621853]
#  [ 24.963596 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 3  iteration: 5
# got a loss of: 0.021937305
# the forecast of first 5 normalised are: [[-0.02353752]
#  [ 0.09093964]
#  [ 0.2058065 ]
#  [ 0.20196164]
#  [ 0.11511922]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[-12.757334]
#  [ 49.289284]
#  [111.54712 ]
#  [109.4632  ]
#  [ 62.394615]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 3  iteration: 6
# got a loss of: 0.038978696
# the forecast of first 5 normalised are: [[0.20610678]
#  [0.26620424]
#  [0.31494892]
#  [0.17912602]
#  [0.20082927]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[111.70988 ]
#  [144.2827  ]
#  [170.70232 ]
#  [ 97.0863  ]
#  [108.849464]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 3  iteration: 7
# got a loss of: 0.06476112
# the forecast of first 5 normalised are: [[0.25408423]
#  [0.3060193 ]
#  [0.36745048]
#  [0.19800305]
#  [0.3936646 ]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[137.71365]
#  [165.86246]
#  [199.15816]
#  [107.31766]
#  [213.36621]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 3  iteration: 7
# got a loss of: 0.08245442
# the forecast of first 5 normalised are: [[0.37350845]
#  [0.3465513 ]
#  [0.4189539 ]
#  [0.45882463]
#  [0.2748301 ]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[202.44159]
#  [187.83081]
#  [227.07301]
#  [248.68295]
#  [148.95792]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.336452  ]
#  [0.32665431]
#  [0.29802132]
#  [0.2443496 ]
#  [0.27583444]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[182.357  ]
#  [177.04665]
#  [161.52756]
#  [132.43748]
#  [149.50227]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 3 . Total validation loss: 0.08902846276760101
# starting training for epoch: 4
# epoch: 4  iteration: 1
# got a loss of: 0.0847655
# the forecast of first 5 normalised are: [[0.4287274 ]
#  [0.34683406]
#  [0.30028903]
#  [0.39549637]
#  [0.26902318]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[232.37024]
#  [187.98407]
#  [162.75665]
#  [214.35904]
#  [145.81056]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 4  iteration: 2
# got a loss of: 0.085721724
# the forecast of first 5 normalised are: [[0.4038416 ]
#  [0.38462293]
#  [0.48081863]
#  [0.34084976]
#  [0.44756007]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[218.88216]
#  [208.46562]
#  [260.6037 ]
#  [184.74057]
#  [242.57756]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 4  iteration: 3
# got a loss of: 0.079188816
# the forecast of first 5 normalised are: [[0.40842533]
#  [0.34905076]
#  [0.41751122]
#  [0.4558947 ]
#  [0.36420107]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[221.36653]
#  [189.18552]
#  [226.29108]
#  [247.09492]
#  [197.39697]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 4  iteration: 4
# got a loss of: 0.05687077
# the forecast of first 5 normalised are: [[0.34030545]
#  [0.22509193]
#  [0.30849838]
#  [0.3029344 ]
#  [0.34976864]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[184.44556]
#  [121.99983]
#  [167.20612]
#  [164.19044]
#  [189.5746 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 4  iteration: 5
# got a loss of: 0.04178256
# the forecast of first 5 normalised are: [[0.1349206 ]
#  [0.29064238]
#  [0.38407338]
#  [0.35116065]
#  [0.25408196]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 73.12696]
#  [157.52817]
#  [208.16777]
#  [190.32907]
#  [137.71242]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 4  iteration: 6
# got a loss of: 0.04239987
# the forecast of first 5 normalised are: [[0.19299221]
#  [0.28220367]
#  [0.18884373]
#  [0.16808462]
#  [0.19960797]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[104.601776]
#  [152.95439 ]
#  [102.3533  ]
#  [ 91.10187 ]
#  [108.187515]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 4  iteration: 7
# got a loss of: 0.02794283
# the forecast of first 5 normalised are: [[0.12091768]
#  [0.16587579]
#  [0.19347703]
#  [0.08558547]
#  [0.26066983]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 65.537384]
#  [ 89.90468 ]
#  [104.864555]
#  [ 46.38733 ]
#  [141.28305 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 4  iteration: 7
# got a loss of: 0.025271181
# the forecast of first 5 normalised are: [[ 0.09128487]
#  [ 0.1141386 ]
#  [ 0.16082919]
#  [ 0.21728826]
#  [-0.00242186]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 49.4764   ]
#  [ 61.86312  ]
#  [ 87.16942  ]
#  [117.77023  ]
#  [ -1.3126459]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[ 0.04856062]
#  [ 0.03694499]
#  [ 0.01264977]
#  [-0.04248297]
#  [-0.02059627]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[ 26.319855]
#  [ 20.024181]
#  [  6.856178]
#  [-23.02577 ]
#  [-11.163176]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 4 . Total validation loss: 0.19970695301890373
# starting training for epoch: 5
# epoch: 5  iteration: 1
# got a loss of: 0.03229512
# the forecast of first 5 normalised are: [[ 0.08759153]
#  [ 0.05420995]
#  [ 0.0156256 ]
#  [ 0.10516   ]
#  [-0.02283418]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[ 47.47461 ]
#  [ 29.381792]
#  [  8.469073]
#  [ 56.99672 ]
#  [-12.376126]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 5  iteration: 2
# got a loss of: 0.036088675
# the forecast of first 5 normalised are: [[0.07449377]
#  [0.05379927]
#  [0.17009902]
#  [0.00697494]
#  [0.10689962]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[40.37562 ]
#  [29.159204]
#  [92.19367 ]
#  [ 3.780415]
#  [57.939594]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 5  iteration: 3
# got a loss of: 0.03307552
# the forecast of first 5 normalised are: [[0.09607363]
#  [0.04158926]
#  [0.10107934]
#  [0.1465553 ]
#  [0.0331167 ]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[52.071907]
#  [22.541378]
#  [54.785004]
#  [79.432976]
#  [17.949251]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 5  iteration: 4
# got a loss of: 0.035049092
# the forecast of first 5 normalised are: [[ 0.05215549]
#  [-0.06375647]
#  [ 0.02753639]
#  [ 0.0143075 ]
#  [ 0.06152558]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 28.268278 ]
#  [-34.556004 ]
#  [ 14.924725 ]
#  [  7.7546644]
#  [ 33.346867 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 5  iteration: 5
# got a loss of: 0.037577998
# the forecast of first 5 normalised are: [[-0.09169829]
#  [ 0.05410981]
#  [ 0.14515924]
#  [ 0.11306334]
#  [ 0.01747048]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[-49.700474]
#  [ 29.327518]
#  [ 78.67631 ]
#  [ 61.280327]
#  [  9.469   ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 5  iteration: 6
# got a loss of: 0.03845818
# the forecast of first 5 normalised are: [[0.02217913]
#  [0.10261607]
#  [0.01088727]
#  [0.00215864]
#  [0.0285722 ]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[12.021087 ]
#  [55.617912 ]
#  [ 5.900898 ]
#  [ 1.1699839]
#  [15.486134 ]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 5  iteration: 7
# got a loss of: 0.026162874
# the forecast of first 5 normalised are: [[ 0.02281976]
#  [ 0.06083274]
#  [ 0.08730614]
#  [-0.02213287]
#  [ 0.15027094]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 12.368309]
#  [ 32.971344]
#  [ 47.319927]
#  [-11.996017]
#  [ 81.446846]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 5  iteration: 7
# got a loss of: 0.026136165
# the forecast of first 5 normalised are: [[ 0.06017363]
#  [ 0.07949317]
#  [ 0.12310708]
#  [ 0.17615294]
#  [-0.02411234]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 32.61411 ]
#  [ 43.085297]
#  [ 66.72404 ]
#  [ 95.4749  ]
#  [-13.068891]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[ 0.08161557]
#  [ 0.07158995]
#  [ 0.04929399]
#  [-0.00817382]
#  [ 0.01719201]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[44.235638]
#  [38.80175 ]
#  [26.717346]
#  [-4.430212]
#  [ 9.318068]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 5 . Total validation loss: 0.16545474156737328
# starting training for epoch: 6
# epoch: 6  iteration: 1
# got a loss of: 0.028466549
# the forecast of first 5 normalised are: [[0.11825919]
#  [0.0875361 ]
#  [0.0536387 ]
#  [0.13101459]
#  [0.01209378]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[64.09648 ]
#  [47.444565]
#  [29.072174]
#  [71.0099  ]
#  [ 6.55483 ]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 6  iteration: 2
# got a loss of: 0.028104912
# the forecast of first 5 normalised are: [[0.15678394]
#  [0.13792062]
#  [0.24654818]
#  [0.0961684 ]
#  [0.19022608]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 84.9769  ]
#  [ 74.752975]
#  [133.6291  ]
#  [ 52.123272]
#  [103.10253 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 6  iteration: 3
# got a loss of: 0.027126124
# the forecast of first 5 normalised are: [[0.21622288]
#  [0.16466677]
#  [0.22200012]
#  [0.26388133]
#  [0.1597004 ]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[117.1928  ]
#  [ 89.24939 ]
#  [120.324066]
#  [143.02368 ]
#  [ 86.55762 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 6  iteration: 4
# got a loss of: 0.02593662
# the forecast of first 5 normalised are: [[0.20036542]
#  [0.09456265]
#  [0.1761626 ]
#  [0.16465938]
#  [0.20978427]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[108.59806 ]
#  [ 51.252956]
#  [ 95.48013 ]
#  [ 89.245384]
#  [113.70307 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 6  iteration: 5
# got a loss of: 0.026872782
# the forecast of first 5 normalised are: [[0.07249355]
#  [0.20830417]
#  [0.2951926 ]
#  [0.2659197 ]
#  [0.1768558 ]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 39.291504]
#  [112.900856]
#  [159.99438 ]
#  [144.12846 ]
#  [ 95.85584 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 6  iteration: 6
# got a loss of: 0.03655165
# the forecast of first 5 normalised are: [[0.1735487 ]
#  [0.2476809 ]
#  [0.16601062]
#  [0.15508556]
#  [0.17921245]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[ 94.06339]
#  [134.24304]
#  [ 89.97775]
#  [ 84.05637]
#  [ 97.13315]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 6  iteration: 7
# got a loss of: 0.028858712
# the forecast of first 5 normalised are: [[0.15487719]
#  [0.18936133]
#  [0.21499205]
#  [0.1068927 ]
#  [0.2738831 ]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 83.943436]
#  [102.63384 ]
#  [116.52569 ]
#  [ 57.935844]
#  [148.44464 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 6  iteration: 7
# got a loss of: 0.025599744
# the forecast of first 5 normalised are: [[0.16100919]
#  [0.1778748 ]
#  [0.21911669]
#  [0.26945424]
#  [0.08120465]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 87.26698 ]
#  [ 96.40814 ]
#  [118.761246]
#  [146.0442  ]
#  [ 44.01292 ]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.14505315]
#  [0.13559306]
#  [0.11487949]
#  [0.05658472]
#  [0.08379042]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[78.618805]
#  [73.49144 ]
#  [62.264683]
#  [30.668917]
#  [45.41441 ]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 6 . Total validation loss: 0.11924890615046024
# starting training for epoch: 7
# epoch: 7  iteration: 1
# got a loss of: 0.027547795
# the forecast of first 5 normalised are: [[0.18020487]
#  [0.1504153 ]
#  [0.11958098]
#  [0.18995953]
#  [0.07743967]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[ 97.671036]
#  [ 81.52509 ]
#  [ 64.8129  ]
#  [102.95806 ]
#  [ 41.972298]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 7  iteration: 2
# got a loss of: 0.027757348
# the forecast of first 5 normalised are: [[0.17793345]
#  [0.1605103 ]
#  [0.26210034]
#  [0.12189662]
#  [0.21152496]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 96.43993]
#  [ 86.99658]
#  [142.05838]
#  [ 66.06797]
#  [114.64653]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 7  iteration: 3
# got a loss of: 0.025243785
# the forecast of first 5 normalised are: [[0.1973368 ]
#  [0.14817941]
#  [0.20381403]
#  [0.24222279]
#  [0.14660084]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[106.95654]
#  [ 80.31324]
#  [110.4672 ]
#  [131.28474]
#  [ 79.45766]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 7  iteration: 4
# got a loss of: 0.023114458
# the forecast of first 5 normalised are: [[0.15235949]
#  [0.05476999]
#  [0.12741935]
#  [0.11838138]
#  [0.16159165]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[82.57884 ]
#  [29.685337]
#  [69.06129 ]
#  [64.16271 ]
#  [87.58267 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 7  iteration: 5
# got a loss of: 0.024621291
# the forecast of first 5 normalised are: [[0.0037812 ]
#  [0.13166761]
#  [0.21529675]
#  [0.18914938]
#  [0.10560668]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[  2.04941 ]
#  [ 71.363846]
#  [116.690834]
#  [102.51897 ]
#  [ 57.23882 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 7  iteration: 6
# got a loss of: 0.030930324
# the forecast of first 5 normalised are: [[0.08565557]
#  [0.15371168]
#  [0.0824579 ]
#  [0.06848621]
#  [0.09045935]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[46.42532 ]
#  [83.31173 ]
#  [44.69218 ]
#  [37.11953 ]
#  [49.028965]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 7  iteration: 7
# got a loss of: 0.02232307
# the forecast of first 5 normalised are: [[0.06117141]
#  [0.09323227]
#  [0.11866426]
#  [0.01040995]
#  [0.1732322 ]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[33.154907]
#  [50.53189 ]
#  [64.31603 ]
#  [ 5.642194]
#  [93.89185 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 7  iteration: 7
# got a loss of: 0.024086956
# the forecast of first 5 normalised are: [[ 0.07139444]
#  [ 0.0853163 ]
#  [ 0.12493873]
#  [ 0.1723845 ]
#  [-0.00418127]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[38.69579 ]
#  [46.241436]
#  [67.71679 ]
#  [93.432396]
#  [-2.266246]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[ 0.06606019]
#  [ 0.05725253]
#  [ 0.0377121 ]
#  [-0.02084124]
#  [ 0.00810027]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[ 35.80462 ]
#  [ 31.030869]
#  [ 20.439957]
#  [-11.295953]
#  [  4.390347]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 7 . Total validation loss: 0.17111125960946083
# starting training for epoch: 8
# epoch: 8  iteration: 1
# got a loss of: 0.028534045
# the forecast of first 5 normalised are: [[0.10086131]
#  [0.07133186]
#  [0.04252374]
#  [0.10747623]
#  [0.00052238]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[54.666832 ]
#  [38.66187  ]
#  [23.047869 ]
#  [58.25212  ]
#  [ 0.2831273]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 8  iteration: 2
# got a loss of: 0.02783668
# the forecast of first 5 normalised are: [[0.11573923]
#  [0.09954596]
#  [0.19468021]
#  [0.06388855]
#  [0.14932287]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 62.73066 ]
#  [ 53.953907]
#  [105.51668 ]
#  [ 34.627594]
#  [ 80.93299 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 8  iteration: 3
# got a loss of: 0.024156647
# the forecast of first 5 normalised are: [[0.15624332]
#  [0.10952067]
#  [0.16319501]
#  [0.19861925]
#  [0.11025786]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 84.68388 ]
#  [ 59.360207]
#  [ 88.4517  ]
#  [107.651634]
#  [ 59.75976 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 8  iteration: 4
# got a loss of: 0.02281451
# the forecast of first 5 normalised are: [[0.13911688]
#  [0.04838371]
#  [0.11443663]
#  [0.10691869]
#  [0.14807093]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[75.40135 ]
#  [26.223972]
#  [62.02465 ]
#  [57.949932]
#  [80.25445 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 8  iteration: 5
# got a loss of: 0.023549074
# the forecast of first 5 normalised are: [[0.01994264]
#  [0.14132118]
#  [0.22106111]
#  [0.19711435]
#  [0.11836207]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 10.808911]
#  [ 76.596085]
#  [119.815125]
#  [106.835976]
#  [ 64.152245]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 8  iteration: 6
# got a loss of: 0.030074079
# the forecast of first 5 normalised are: [[0.11961842]
#  [0.18292117]
#  [0.11807978]
#  [0.10344195]
#  [0.12389815]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[64.83318 ]
#  [99.14327 ]
#  [63.99924 ]
#  [56.06554 ]
#  [67.152794]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 8  iteration: 7
# got a loss of: 0.02219768
# the forecast of first 5 normalised are: [[0.11174691]
#  [0.14158046]
#  [0.16585624]
#  [0.05980134]
#  [0.2172271 ]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 60.566822]
#  [ 76.73661 ]
#  [ 89.89408 ]
#  [ 32.412327]
#  [117.73709 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 8  iteration: 7
# got a loss of: 0.021842822
# the forecast of first 5 normalised are: [[0.13063192]
#  [0.14341903]
#  [0.18064475]
#  [0.22580457]
#  [0.05900133]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 70.802505]
#  [ 77.733116]
#  [ 97.909454]
#  [122.38608 ]
#  [ 31.97872 ]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.12795484]
#  [0.1196152 ]
#  [0.10120165]
#  [0.04253042]
#  [0.07272768]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[69.351524]
#  [64.831436]
#  [54.851295]
#  [23.051487]
#  [39.418404]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 8 . Total validation loss: 0.12398689985275269
# starting training for epoch: 9
# epoch: 9  iteration: 1
# got a loss of: 0.02540885
# the forecast of first 5 normalised are: [[0.16078782]
#  [0.13293815]
#  [0.10586572]
#  [0.16655052]
#  [0.06456292]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[87.146996]
#  [72.052475]
#  [57.37922 ]
#  [90.27038 ]
#  [34.9931  ]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 9  iteration: 2
# got a loss of: 0.026104884
# the forecast of first 5 normalised are: [[0.17076969]
#  [0.1557163 ]
#  [0.24535823]
#  [0.12238848]
#  [0.20337605]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 92.557175]
#  [ 84.39823 ]
#  [132.98416 ]
#  [ 66.33456 ]
#  [110.22982 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 9  iteration: 3
# got a loss of: 0.024434002
# the forecast of first 5 normalised are: [[0.19971192]
#  [0.15563309]
#  [0.20667315]
#  [0.23992038]
#  [0.15718377]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[108.24386 ]
#  [ 84.353134]
#  [112.016846]
#  [130.03685 ]
#  [ 85.1936  ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 9  iteration: 4
# got a loss of: 0.022315016
# the forecast of first 5 normalised are: [[0.1709981 ]
#  [0.08658934]
#  [0.14720464]
#  [0.1406368 ]
#  [0.17962682]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[92.68097 ]
#  [46.93142 ]
#  [79.78491 ]
#  [76.22514 ]
#  [97.357735]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 9  iteration: 5
# got a loss of: 0.022728855
# the forecast of first 5 normalised are: [[0.04070926]
#  [0.15629947]
#  [0.23216605]
#  [0.21033585]
#  [0.13607371]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 22.064417]
#  [ 84.71432 ]
#  [125.834   ]
#  [114.00203 ]
#  [ 73.75195 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 9  iteration: 6
# got a loss of: 0.029378913
# the forecast of first 5 normalised are: [[0.12137187]
#  [0.17969573]
#  [0.12186956]
#  [0.1061461 ]
#  [0.12503612]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[65.783554]
#  [97.39508 ]
#  [66.05331 ]
#  [57.531185]
#  [67.76958 ]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 9  iteration: 7
# got a loss of: 0.020888379
# the forecast of first 5 normalised are: [[0.0987438 ]
#  [0.12657428]
#  [0.15017593]
#  [0.04441249]
#  [0.19794118]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 53.51914 ]
#  [ 68.60326 ]
#  [ 81.395355]
#  [ 24.071571]
#  [107.28412 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 9  iteration: 7
# got a loss of: 0.021165784
# the forecast of first 5 normalised are: [[0.10573876]
#  [0.11620772]
#  [0.15159976]
#  [0.19417655]
#  [0.03775048]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 57.310406]
#  [ 62.984585]
#  [ 82.167076]
#  [105.24369 ]
#  [ 20.460762]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.09360039]
#  [0.08584476]
#  [0.06817269]
#  [0.0088762 ]
#  [0.04108608]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[50.73141  ]
#  [46.52786  ]
#  [36.9496   ]
#  [ 4.8109026]
#  [22.268654 ]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 9 . Total validation loss: 0.14402149058878422
# starting training for epoch: 10
# epoch: 10  iteration: 1
# got a loss of: 0.025440346
# the forecast of first 5 normalised are: [[0.12622201]
#  [0.0985918 ]
#  [0.07278669]
#  [0.12924099]
#  [0.03165007]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[68.41233 ]
#  [53.43676 ]
#  [39.450386]
#  [70.048615]
#  [17.154335]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 10  iteration: 2
# got a loss of: 0.025510794
# the forecast of first 5 normalised are: [[0.1313287 ]
#  [0.11751068]
#  [0.20075285]
#  [0.0873009 ]
#  [0.16421902]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 71.18015 ]
#  [ 63.69079 ]
#  [108.808044]
#  [ 47.317085]
#  [ 89.00671 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 10  iteration: 3
# got a loss of: 0.022823922
# the forecast of first 5 normalised are: [[0.15967572]
#  [0.11797369]
#  [0.16734648]
#  [0.19734156]
#  [0.12226748]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 86.544235]
#  [ 63.94174 ]
#  [ 90.70179 ]
#  [106.95913 ]
#  [ 66.268974]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 10  iteration: 4
# got a loss of: 0.02174518
# the forecast of first 5 normalised are: [[0.14007461]
#  [0.0630424 ]
#  [0.11577153]
#  [0.11132205]
#  [0.14841652]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[75.92044 ]
#  [34.168983]
#  [62.74817 ]
#  [60.336548]
#  [80.44176 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 10  iteration: 5
# got a loss of: 0.022603402
# the forecast of first 5 normalised are: [[0.02200174]
#  [0.1319896 ]
#  [0.20442688]
#  [0.1854012 ]
#  [0.11575997]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 11.924945]
#  [ 71.53836 ]
#  [110.79937 ]
#  [100.48745 ]
#  [ 62.7419  ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 10  iteration: 6
# got a loss of: 0.028495826
# the forecast of first 5 normalised are: [[0.11253393]
#  [0.16545689]
#  [0.1157949 ]
#  [0.09821725]
#  [0.11544096]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[60.99339 ]
#  [89.677635]
#  [62.760834]
#  [53.23375 ]
#  [62.569004]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 10  iteration: 7
# got a loss of: 0.020254908
# the forecast of first 5 normalised are: [[0.10165119]
#  [0.1274854 ]
#  [0.15044427]
#  [0.04451072]
#  [0.19459784]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 55.094948]
#  [ 69.097084]
#  [ 81.540794]
#  [ 24.124811]
#  [105.47203 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 10  iteration: 7
# got a loss of: 0.020345569
# the forecast of first 5 normalised are: [[0.11915827]
#  [0.1276586 ]
#  [0.16099274]
#  [0.20112205]
#  [0.05468512]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 64.58378 ]
#  [ 69.19096 ]
#  [ 87.258064]
#  [109.00815 ]
#  [ 29.639332]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.11410952]
#  [0.10687637]
#  [0.08996284]
#  [0.03000605]
#  [0.06405354]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[61.84736 ]
#  [57.926994]
#  [48.75986 ]
#  [16.263279]
#  [34.71702 ]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 10 . Total validation loss: 0.12739419378340244
# starting training for epoch: 11
# epoch: 11  iteration: 1
# got a loss of: 0.024156833
# the forecast of first 5 normalised are: [[0.14581048]
#  [0.11902583]
#  [0.09447157]
#  [0.14696348]
#  [0.05355608]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[79.02928 ]
#  [64.512   ]
#  [51.203594]
#  [79.654205]
#  [29.027397]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 11  iteration: 2
# got a loss of: 0.024440944
# the forecast of first 5 normalised are: [[0.1544137 ]
#  [0.14181519]
#  [0.21914804]
#  [0.11440206]
#  [0.18704712]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 83.69222 ]
#  [ 76.86383 ]
#  [118.77824 ]
#  [ 62.005913]
#  [101.37954 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 11  iteration: 3
# got a loss of: 0.022529783
# the forecast of first 5 normalised are: [[0.1817869 ]
#  [0.14263856]
#  [0.18982637]
#  [0.21714175]
#  [0.14865553]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 98.528496]
#  [ 77.310104]
#  [102.885895]
#  [117.69083 ]
#  [ 80.5713  ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 11  iteration: 4
# got a loss of: 0.020979725
# the forecast of first 5 normalised are: [[0.16224158]
#  [0.09248316]
#  [0.1380701 ]
#  [0.13523066]
#  [0.17028797]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[87.93494 ]
#  [50.125874]
#  [74.834   ]
#  [73.29502 ]
#  [92.29608 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 11  iteration: 5
# got a loss of: 0.021516876
# the forecast of first 5 normalised are: [[0.04157281]
#  [0.14608431]
#  [0.21496582]
#  [0.19882107]
#  [0.13388932]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 22.532463]
#  [ 79.1777  ]
#  [116.511475]
#  [107.76102 ]
#  [ 72.56801 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 11  iteration: 6
# got a loss of: 0.027800197
# the forecast of first 5 normalised are: [[0.12316394]
#  [0.1700654 ]
#  [0.13030899]
#  [0.10965216]
#  [0.12509882]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[66.75485 ]
#  [92.175446]
#  [70.62747 ]
#  [59.431473]
#  [67.803566]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 11  iteration: 7
# got a loss of: 0.019473784
# the forecast of first 5 normalised are: [[0.10295832]
#  [0.12672603]
#  [0.14974678]
#  [0.04077554]
#  [0.18955505]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[ 55.80341 ]
#  [ 68.68551 ]
#  [ 81.16275 ]
#  [ 22.100342]
#  [102.73884 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 11  iteration: 7
# got a loss of: 0.019730598
# the forecast of first 5 normalised are: [[0.11351717]
#  [0.11814988]
#  [0.14977479]
#  [0.18728936]
#  [0.05142176]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[ 61.526302]
#  [ 64.03723 ]
#  [ 81.17793 ]
#  [101.51083 ]
#  [ 27.870594]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.09883738]
#  [0.09189558]
#  [0.07523918]
#  [0.01324093]
#  [0.05043089]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[53.56986 ]
#  [49.807404]
#  [40.779636]
#  [ 7.176586]
#  [27.333544]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 11 . Total validation loss: 0.1336663831025362
# starting training for epoch: 12
# epoch: 12  iteration: 1
# got a loss of: 0.02394873
# the forecast of first 5 normalised are: [[0.131706  ]
#  [0.10331118]
#  [0.07981181]
#  [0.12786293]
#  [0.03778887]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[71.38465 ]
#  [55.99466 ]
#  [43.258003]
#  [69.30171 ]
#  [20.481567]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 12  iteration: 2
# got a loss of: 0.023842625
# the forecast of first 5 normalised are: [[0.13518763]
#  [0.12439215]
#  [0.1935395 ]
#  [0.10084462]
#  [0.17024863]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[ 73.27169 ]
#  [ 67.42055 ]
#  [104.89841 ]
#  [ 54.657784]
#  [ 92.27476 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 12  iteration: 3
# ...
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 57.889973]
#  [ 75.37602 ]
#  [ 76.14225 ]
#  [ 35.501465]
#  [126.05077 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 97  iteration: 4
# got a loss of: 0.012295605
# the forecast of first 5 normalised are: [[0.16278183]
#  [0.3034284 ]
#  [0.1191771 ]
#  [0.1845758 ]
#  [0.16337085]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 88.22775 ]
#  [164.4582  ]
#  [ 64.59399 ]
#  [100.040085]
#  [ 88.547   ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 97  iteration: 5
# got a loss of: 0.010519998
# the forecast of first 5 normalised are: [[0.12227917]
#  [0.0718286 ]
#  [0.03960276]
#  [0.12537181]
#  [0.19489086]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 66.27531 ]
#  [ 38.931103]
#  [ 21.464695]
#  [ 67.95152 ]
#  [105.630844]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 97  iteration: 6
# got a loss of: 0.017609445
# the forecast of first 5 normalised are: [[0.22912908]
#  [0.10370815]
#  [0.3070711 ]
#  [0.23275602]
#  [0.20396936]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[124.18796 ]
#  [ 56.209816]
#  [166.43253 ]
#  [126.15376 ]
#  [110.55139 ]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 97  iteration: 7
# got a loss of: 0.008383863
# the forecast of first 5 normalised are: [[0.17723489]
#  [0.14879942]
#  [0.16848004]
#  [0.02521884]
#  [0.08830142]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[96.06131 ]
#  [80.649284]
#  [91.31618 ]
#  [13.668613]
#  [47.85937 ]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 97  iteration: 7
# got a loss of: 0.013616283
# the forecast of first 5 normalised are: [[0.1956718 ]
#  [0.11423075]
#  [0.08522677]
#  [0.04863882]
#  [0.18998623]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[106.054115]
#  [ 61.913067]
#  [ 46.192913]
#  [ 26.36224 ]
#  [102.972534]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.15969014]
#  [0.1633048 ]
#  [0.15098   ]
#  [0.08951688]
#  [0.15903091]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[86.552055]
#  [88.51121 ]
#  [81.83116 ]
#  [48.518147]
#  [86.194756]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 97 . Total validation loss: 0.049825288355350494
# starting training for epoch: 98
# epoch: 98  iteration: 1
# got a loss of: 0.012279454
# the forecast of first 5 normalised are: [[0.20341599]
#  [0.16445732]
#  [0.15773213]
#  [0.10559475]
#  [0.11539268]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[110.251465]
#  [ 89.135864]
#  [ 85.490814]
#  [ 57.232357]
#  [ 62.542835]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 98  iteration: 2
# got a loss of: 0.015875736
# the forecast of first 5 normalised are: [[0.19916403]
#  [0.22904432]
#  [0.10422266]
#  [0.28942013]
#  [0.24886084]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[107.94691 ]
#  [124.14202 ]
#  [ 56.488678]
#  [156.8657  ]
#  [134.88257 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 98  iteration: 3
# got a loss of: 0.010609643
# the forecast of first 5 normalised are: [[0.10428393]
#  [0.13784528]
#  [0.13997972]
#  [0.06093669]
#  [0.23771822]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 56.52189 ]
#  [ 74.71214 ]
#  [ 75.86901 ]
#  [ 33.027687]
#  [128.84328 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 98  iteration: 4
# got a loss of: 0.014426602
# the forecast of first 5 normalised are: [[0.13955128]
#  [0.2986933 ]
#  [0.09211993]
#  [0.1630727 ]
#  [0.14092624]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 75.636795]
#  [161.89177 ]
#  [ 49.929005]
#  [ 88.38541 ]
#  [ 76.38203 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 98  iteration: 5
# got a loss of: 0.010191721
# the forecast of first 5 normalised are: [[0.13158453]
#  [0.07741559]
#  [0.04460776]
#  [0.13306403]
#  [0.20474744]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 71.31881 ]
#  [ 41.959248]
#  [ 24.177404]
#  [ 72.120705]
#  [110.973114]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 98  iteration: 6
# got a loss of: 0.019864475
# the forecast of first 5 normalised are: [[0.25282443]
#  [0.12762487]
#  [0.32949245]
#  [0.2566986 ]
#  [0.22798884]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[137.03084 ]
#  [ 69.172676]
#  [178.58492 ]
#  [139.13065 ]
#  [123.569954]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 98  iteration: 7
# got a loss of: 0.008306025
# the forecast of first 5 normalised are: [[0.1771791 ]
#  [0.14771712]
#  [0.1685201 ]
#  [0.02295732]
#  [0.08609164]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[96.031075]
#  [80.062675]
#  [91.33789 ]
#  [12.44287 ]
#  [46.661667]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 98  iteration: 7
# got a loss of: 0.016526524
# the forecast of first 5 normalised are: [[0.17649853]
#  [0.09003246]
#  [0.05943143]
#  [0.0233084 ]
#  [0.1701597 ]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[95.6622  ]
#  [48.797592]
#  [32.211838]
#  [12.633151]
#  [92.226555]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.16604137]
#  [0.16953838]
#  [0.15708125]
#  [0.09587157]
#  [0.16537559]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[89.99442]
#  [91.8898 ]
#  [85.13804]
#  [51.96239]
#  [89.63357]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 98 . Total validation loss: 0.0478467782959342
# starting training for epoch: 99
# epoch: 99  iteration: 1
# got a loss of: 0.012097959
# the forecast of first 5 normalised are: [[0.21058631]
#  [0.17059791]
#  [0.16380847]
#  [0.11159134]
#  [0.12157893]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[114.13778 ]
#  [ 92.464066]
#  [ 88.78419 ]
#  [ 60.482506]
#  [ 65.89578 ]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 99  iteration: 2
# got a loss of: 0.018505102
# the forecast of first 5 normalised are: [[0.21903646]
#  [0.247944  ]
#  [0.1261096 ]
#  [0.30656922]
#  [0.2667638 ]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[118.71776]
#  [134.38565]
#  [ 68.3514 ]
#  [166.16052]
#  [144.58598]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 99  iteration: 3
# got a loss of: 0.0107652955
# the forecast of first 5 normalised are: [[0.11060536]
#  [0.1430682 ]
#  [0.14622712]
#  [0.06819105]
#  [0.24346519]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 59.948105]
#  [ 77.54296 ]
#  [ 79.2551  ]
#  [ 36.95955 ]
#  [131.95813 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 99  iteration: 4
# got a loss of: 0.016639842
# the forecast of first 5 normalised are: [[0.12157881]
#  [0.28737557]
#  [0.07431734]
#  [0.1453197 ]
#  [0.1238991 ]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 65.89571 ]
#  [155.75755 ]
#  [ 40.279995]
#  [ 78.763275]
#  [ 67.15331 ]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 99  iteration: 5
# got a loss of: 0.01041762
# the forecast of first 5 normalised are: [[0.12436235]
#  [0.07025135]
#  [0.03878248]
#  [0.12644148]
#  [0.19789135]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[ 67.404396]
#  [ 38.07623 ]
#  [ 21.020103]
#  [ 68.53128 ]
#  [107.25711 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 99  iteration: 6
# got a loss of: 0.021438686
# the forecast of first 5 normalised are: [[0.26176572]
#  [0.14258432]
#  [0.33301985]
#  [0.2649759 ]
#  [0.2379992 ]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[141.87701]
#  [ 77.2807 ]
#  [180.49677]
#  [143.61694]
#  [128.99556]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 99  iteration: 7
# got a loss of: 0.009437047
# the forecast of first 5 normalised are: [[0.19396937]
#  [0.1673727 ]
#  [0.18682182]
#  [0.0449909 ]
#  [0.10973918]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[105.1314  ]
#  [ 90.716   ]
#  [101.25742 ]
#  [ 24.385067]
#  [ 59.478638]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 99  iteration: 7
# got a loss of: 0.016527617
# the forecast of first 5 normalised are: [[0.17061317]
#  [0.08856988]
#  [0.05935049]
#  [0.02738547]
#  [0.16004705]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[92.472336]
#  [48.004875]
#  [32.167965]
#  [14.842926]
#  [86.74551 ]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.13283384]
#  [0.1337297 ]
#  [0.12045288]
#  [0.05967224]
#  [0.12725627]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[71.99594 ]
#  [72.4815  ]
#  [65.28546 ]
#  [32.342354]
#  [68.9729  ]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 99 . Total validation loss: 0.05846843030303717
# starting training for epoch: 100
# epoch: 100  iteration: 1
# got a loss of: 0.013866015
# the forecast of first 5 normalised are: [[0.17596638]
#  [0.13195956]
#  [0.12575042]
#  [0.0775789 ]
#  [0.08493316]]
# while the actuals were normalised     : [[0.18634686]
#  [0.19926199]
#  [0.25830258]
#  [0.23800738]
#  [0.42804428]]
# the forecast of first 5 orignal scale are: [[95.37378 ]
#  [71.52208 ]
#  [68.15673 ]
#  [42.047764]
#  [46.033775]]
# while the actuals were original scale     : [[101.]
#  [108.]
#  [140.]
#  [129.]
#  [232.]]
# epoch: 100  iteration: 2
# got a loss of: 0.017562706
# the forecast of first 5 normalised are: [[0.21163762]
#  [0.23921132]
#  [0.12369108]
#  [0.29467225]
#  [0.25784218]]
# while the actuals were normalised     : [[0.20110701]
#  [0.17158672]
#  [0.        ]
#  [0.17343173]
#  [0.2195572 ]]
# the forecast of first 5 orignal scale are: [[114.70759 ]
#  [129.65254 ]
#  [ 67.040565]
#  [159.71236 ]
#  [139.75046 ]]
# while the actuals were original scale     : [[109.]
#  [ 93.]
#  [  0.]
#  [ 94.]
#  [119.]]
# epoch: 100  iteration: 3
# got a loss of: 0.013526623
# the forecast of first 5 normalised are: [[0.15219533]
#  [0.18109083]
#  [0.18325949]
#  [0.11436522]
#  [0.26698995]]
# while the actuals were normalised     : [[0.09225092]
#  [0.1900369 ]
#  [0.22509225]
#  [0.14206642]
#  [0.22140221]]
# the forecast of first 5 orignal scale are: [[ 82.48987 ]
#  [ 98.15123 ]
#  [ 99.326645]
#  [ 61.98595 ]
#  [144.70856 ]]
# while the actuals were original scale     : [[ 50.]
#  [103.]
#  [122.]
#  [ 77.]
#  [120.]]
# epoch: 100  iteration: 4
# got a loss of: 0.013153192
# the forecast of first 5 normalised are: [[0.14849317]
#  [0.2924745 ]
#  [0.10734367]
#  [0.16980433]
#  [0.15083528]]
# while the actuals were normalised     : [[0.32287823]
#  [0.00922509]
#  [0.16789668]
#  [0.44464945]
#  [0.33210332]]
# the forecast of first 5 orignal scale are: [[ 80.4833  ]
#  [158.52118 ]
#  [ 58.18027 ]
#  [ 92.03395 ]
#  [ 81.752716]]
# while the actuals were original scale     : [[175.]
#  [  5.]
#  [ 91.]
#  [241.]
#  [180.]]
# epoch: 100  iteration: 5
# got a loss of: 0.01453619
# the forecast of first 5 normalised are: [[ 0.07969463]
#  [ 0.02724433]
#  [-0.00218177]
#  [ 0.07900488]
#  [ 0.15113378]]
# while the actuals were normalised     : [[0.18265683]
#  [0.00553506]
#  [0.        ]
#  [0.14391144]
#  [0.47416974]]
# the forecast of first 5 orignal scale are: [[43.19449  ]
#  [14.766426 ]
#  [-1.1825185]
#  [42.82065  ]
#  [81.914505 ]]
# while the actuals were original scale     : [[ 99.]
#  [  3.]
#  [  0.]
#  [ 78.]
#  [257.]]
# epoch: 100  iteration: 6
# got a loss of: 0.017295519
# the forecast of first 5 normalised are: [[0.2184068 ]
#  [0.10117185]
#  [0.29479897]
#  [0.21977401]
#  [0.19331908]]
# while the actuals were normalised     : [[0.16420664]
#  [0.        ]
#  [0.26937269]
#  [0.21217712]
#  [0.09225092]]
# the forecast of first 5 orignal scale are: [[118.37648 ]
#  [ 54.835144]
#  [159.78104 ]
#  [119.117516]
#  [104.778946]]
# while the actuals were original scale     : [[ 89.]
#  [  0.]
#  [146.]
#  [115.]
#  [ 50.]]
# epoch: 100  iteration: 7
# got a loss of: 0.012078535
# the forecast of first 5 normalised are: [[0.21529186]
#  [0.19297087]
#  [0.20965874]
#  [0.07504416]
#  [0.14136767]]
# while the actuals were normalised     : [[0.17343173]
#  [0.21771218]
#  [0.14391144]
#  [0.        ]
#  [0.1900369 ]]
# the forecast of first 5 orignal scale are: [[116.68819]
#  [104.59021]
#  [113.63504]
#  [ 40.67393]
#  [ 76.62128]]
# while the actuals were original scale     : [[ 94.]
#  [118.]
#  [ 78.]
#  [  0.]
#  [103.]]
# epoch: 100  iteration: 7
# got a loss of: 0.011324886
# the forecast of first 5 normalised are: [[0.22068572]
#  [0.15206718]
#  [0.12834668]
#  [0.09769702]
#  [0.2099719 ]]
# while the actuals were normalised     : [[0.17896679]
#  [0.30811808]
#  [0.14944649]
#  [0.        ]
#  [0.3800738 ]]
# the forecast of first 5 orignal scale are: [[119.611664]
#  [ 82.42041 ]
#  [ 69.5639  ]
#  [ 52.951786]
#  [113.80477 ]]
# while the actuals were original scale     : [[ 97.]
#  [167.]
#  [ 81.]
#  [  0.]
#  [206.]]
# starting validation
# first five predictions: [[0.11904824]
#  [0.11861646]
#  [0.10501254]
#  [0.04441035]
#  [0.10937178]]
# first five actuals    : [[0.15682657]
#  [0.14391144]
#  [0.13099631]
#  [0.20848708]
#  [0.25461255]]
# the forecast of first 5 orignal scale are: [[64.52415 ]
#  [64.29012 ]
#  [56.916794]
#  [24.070408]
#  [59.279507]]
# while the actuals were original scale     : [[ 85.]
#  [ 78.]
#  [ 71.]
#  [113.]
#  [138.]]
# Validation completed after epoch: 100 . Total validation loss: 0.06668609846383333
